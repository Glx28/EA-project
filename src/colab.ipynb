# %%
import genetic_algorithm
genetic_algorithm.main()
# Out:
# c:\Users\eduan\Anaconda3\envs\evolcomputation\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import genetic_algorithm
#       2 genetic_algorithm.main()
#
# File c:\Users\eduan\Documents\Personal Coding Projects\NYCU_Evolutionary_Computation\Final Project\src\genetic_algorithm.py:6
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
# ----> 6 from deeplearning import DeepLearningModel
#       9 def accuracy_score(spec, path):
#      10     dlm = DeepLearningModel(path)
#
# File c:\Users\eduan\Documents\Personal Coding Projects\NYCU_Evolutionary_Computation\Final Project\src\deeplearning.py:5
# ...
